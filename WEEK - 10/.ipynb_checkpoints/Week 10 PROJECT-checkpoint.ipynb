# %%
class Zenith:
    def unique_services(self):
        pass

    def mutual_services(self):
        pass


class RetailBanking(Zenith):
    def unique_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance",
            "Retirement and education accounts",
            "Loans and mortgages",
            "Checking and saving",
        ]

    def mutual_services(self):
        return [
            "Investment management and accounts",
            "Insurance",
        ]


class GlobalBanking(Zenith):
    def unique_services(self):
        return [
            "Multi-currency management services and products",
            "Foreign currency accounts",
            "Foreign currency credit cards",
            "Transborder advisory services",
            "Liquidity management",
        ]

    def mutual_services(self):
        return [
            "Investment management and accounts",
            "Insurance",
        ]


class CommercialBanking(Zenith):
    def unique_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance",
            "Advisory services",
        ]

    def mutual_services(self):
        return [
            "Investment management and accounts",
            "Insurance",
        ]


def get_employee_services(employee_name, division):
    if division == "Retail Banking":
        division_obj = RetailBanking()
    elif division == "Global Banking":
        division_obj = GlobalBanking()
    elif division == "Commercial Banking":
        division_obj = CommercialBanking()
    else:
        return "Invalid division"

    unique_services = division_obj.unique_services()
    mutual_services = division_obj.mutual_services()

    if employee_name == "Mary":
        return unique_services
        return mutual_services
    
    elif employee_name == "Agatha" or employee_name == "Noel":
        return mutual_services
        return unique_services
    
    else:
        return "Invalid employee name"


# Example usage
employee_name = input("Enter employee name: ")
division = input("Enter division: ")
services = get_employee_services(employee_name, division)

print(services)
# Out:
# Enter employee name: Noel
# Enter division: Commercial Banking
# ['Investment management and accounts', 'Insurance']
